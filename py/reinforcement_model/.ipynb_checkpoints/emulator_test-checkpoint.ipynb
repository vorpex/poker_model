# %%
import numpy as np
import pandas as pd
import pypokerengine as p
from pypokerengine.api.emulator import Emulator

# %%
emulator = Emulator()

# %%
players_info = {
    'uuid-0': {'name': 'player0', 'stack': 1000},
    'uuid-1': {'name': 'player1', 'stack': 1000},
    'uuid-2': {'name': 'player2', 'stack': 1000},
    'uuid-3': {'name': 'player3', 'stack': 1000},
    'uuid-4': {'name': 'player4', 'stack': 1000},
    'uuid-5': {'name': 'player5', 'stack': 1000}
}

emulator.set_game_rule(player_num=len(players_info),
                       max_round=5,
                       small_blind_amount=10,
                       ante_amount=0)

# %%
initial_state = emulator.generate_initial_game_state(players_info)
initial_state
# Out:
# {'round_count': 0,
#  'small_blind_amount': 10,
#  'street': 0,
#  'next_player': None,
#  'table': <pypokerengine.engine.table.Table at 0x29987339240>}

# %%
i = 0
event = [{'type': ''}]
events = {}

while event[-1]['type'] != 'event_game_finish':
    j = 0
    events[i] = {}
    
    if i == 0:
        game_state, event = emulator.start_new_round(initial_state)
    else:
        game_state, event = emulator.start_new_round(game_state)
    
    events[i][j] = event
    
    while event[-1]['type'] != 'event_round_finish' \
    and event[-1]['type'] != 'event_game_finish':
        j += 1
        
        action = np.random.choice(a=event[-1]['valid_actions'],
                                  size=1,
                                  p=[0.7 if e['action'] == 'call' else 0.3 / (len(event[-1]['valid_actions']) - 1) for e in event[-1]['valid_actions']])[0]['action']
        
        for va in event[-1]['valid_actions']:
            if va['action'] == action and action != 'raise':
                bet_amount = va['amount']
            elif va['action'] == action and action == 'raise':
                flip = np.random.choice(a=['min', 'max'],
                                        size=1,
                                        p=[1/2, 1/2])[0]
                bet_amount = va['amount'][flip]
            else:
                pass
            
        game_state, event = emulator.apply_action(game_state=game_state,
                                                  action=action,
                                                  bet_amount=bet_amount)
        events[i][j] = event
    
    if event[-1]['type'] == 'event_round_finish':
        for player in game_state['table'].seats.players:
            if player.stack == 0:
                player.append_chip(1000)
    
    i += 1

# %%
events
# Out:
# {0: {0: [{'type': 'event_new_street',
#     'street': 'preflop',
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 30}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 0,
#      'next_player': 3,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 1000,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 990,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 1000,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 1000,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 1000,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'}]}}},
#    {'type': 'event_ask_player',
#     'uuid': 'uuid-3',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 1000}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 30}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 0,
#      'next_player': 3,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 1000,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 990,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 1000,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 1000,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 1000,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'}]}}}],
#   1: [{'type': 'event_ask_player',
#     'uuid': 'uuid-4',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 1000}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 50}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 0,
#      'next_player': 4,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 1000,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 990,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 1000,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 1000,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'}]}}}],
#   2: [{'type': 'event_ask_player',
#     'uuid': 'uuid-5',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 1000}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 70}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 0,
#      'next_player': 5,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 1000,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 990,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 1000,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'}]}}}],
#   3: [{'type': 'event_ask_player',
#     'uuid': 'uuid-0',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 1000}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 90}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 0,
#      'next_player': 0,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 1000,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 990,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'}]}}}],
#   4: [{'type': 'event_ask_player',
#     'uuid': 'uuid-1',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 1000}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 110}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 0,
#      'next_player': 1,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 990,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'}]}}}],
#   5: [{'type': 'event_ask_player',
#     'uuid': 'uuid-2',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 1000}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 120}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 0,
#      'next_player': 2,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'}]}}}],
#   6: [{'type': 'event_new_street',
#     'street': 'flop',
#     'round_state': {'street': 'flop',
#      'pot': {'main': {'amount': 120}, 'side': []},
#      'community_card': ['SK', 'S8', 'ST'],
#      'dealer_btn': 0,
#      'next_player': 1,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': []}}},
#    {'type': 'event_ask_player',
#     'uuid': 'uuid-1',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 0},
#      {'action': 'raise', 'amount': {'min': 20, 'max': 980}}],
#     'round_state': {'street': 'flop',
#      'pot': {'main': {'amount': 120}, 'side': []},
#      'community_card': ['SK', 'S8', 'ST'],
#      'dealer_btn': 0,
#      'next_player': 1,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': []}}}],
#   7: [{'type': 'event_ask_player',
#     'uuid': 'uuid-2',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 0},
#      {'action': 'raise', 'amount': {'min': 20, 'max': 980}}],
#     'round_state': {'street': 'flop',
#      'pot': {'main': {'amount': 120}, 'side': []},
#      'community_card': ['SK', 'S8', 'ST'],
#      'dealer_btn': 0,
#      'next_player': 2,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 980, 'state': 'folded'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': [{'action': 'FOLD', 'uuid': 'uuid-1'}]}}}],
#   8: [{'type': 'event_ask_player',
#     'uuid': 'uuid-3',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 40, 'max': 980}}],
#     'round_state': {'street': 'flop',
#      'pot': {'main': {'amount': 140}, 'side': []},
#      'community_card': ['SK', 'S8', 'ST'],
#      'dealer_btn': 0,
#      'next_player': 3,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 980, 'state': 'folded'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 960,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': [{'action': 'FOLD', 'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 20,
#         'paid': 20,
#         'add_amount': 20,
#         'uuid': 'uuid-2'}]}}}],
#   9: [{'type': 'event_ask_player',
#     'uuid': 'uuid-4',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 40, 'max': 980}}],
#     'round_state': {'street': 'flop',
#      'pot': {'main': {'amount': 160}, 'side': []},
#      'community_card': ['SK', 'S8', 'ST'],
#      'dealer_btn': 0,
#      'next_player': 4,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 980, 'state': 'folded'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 960,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 960,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': [{'action': 'FOLD', 'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 20,
#         'paid': 20,
#         'add_amount': 20,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'}]}}}],
#   10: [{'type': 'event_ask_player',
#     'uuid': 'uuid-5',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 40},
#      {'action': 'raise', 'amount': {'min': 60, 'max': 980}}],
#     'round_state': {'street': 'flop',
#      'pot': {'main': {'amount': 200}, 'side': []},
#      'community_card': ['SK', 'S8', 'ST'],
#      'dealer_btn': 0,
#      'next_player': 5,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 980, 'state': 'folded'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 960,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 960,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 940,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': [{'action': 'FOLD', 'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 20,
#         'paid': 20,
#         'add_amount': 20,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'RAISE',
#         'amount': 40,
#         'paid': 40,
#         'add_amount': 20,
#         'uuid': 'uuid-4'}]}}}],
#   11: [{'type': 'event_ask_player',
#     'uuid': 'uuid-0',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 40},
#      {'action': 'raise', 'amount': {'min': 60, 'max': 980}}],
#     'round_state': {'street': 'flop',
#      'pot': {'main': {'amount': 200}, 'side': []},
#      'community_card': ['SK', 'S8', 'ST'],
#      'dealer_btn': 0,
#      'next_player': 0,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 980, 'state': 'folded'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 960,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 960,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 940,
#        'state': 'participating'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 980, 'state': 'folded'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': [{'action': 'FOLD', 'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 20,
#         'paid': 20,
#         'add_amount': 20,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'RAISE',
#         'amount': 40,
#         'paid': 40,
#         'add_amount': 20,
#         'uuid': 'uuid-4'},
#        {'action': 'FOLD', 'uuid': 'uuid-5'}]}}}],
#   12: [{'type': 'event_ask_player',
#     'uuid': 'uuid-2',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 980},
#      {'action': 'raise', 'amount': {'min': -1, 'max': -1}}],
#     'round_state': {'street': 'flop',
#      'pot': {'main': {'amount': 1180},
#       'side': [{'amount': 0, 'eligibles': ['uuid-0']}]},
#      'community_card': ['SK', 'S8', 'ST'],
#      'dealer_btn': 0,
#      'next_player': 2,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 0,
#        'state': 'allin'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 980, 'state': 'folded'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 960,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 960,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 940,
#        'state': 'participating'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 980, 'state': 'folded'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': [{'action': 'FOLD', 'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 20,
#         'paid': 20,
#         'add_amount': 20,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'RAISE',
#         'amount': 40,
#         'paid': 40,
#         'add_amount': 20,
#         'uuid': 'uuid-4'},
#        {'action': 'FOLD', 'uuid': 'uuid-5'},
#        {'action': 'RAISE',
#         'amount': 980,
#         'paid': 980,
#         'add_amount': 940,
#         'uuid': 'uuid-0'}]}}}],
#   13: [{'type': 'event_ask_player',
#     'uuid': 'uuid-3',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 980},
#      {'action': 'raise', 'amount': {'min': -1, 'max': -1}}],
#     'round_state': {'street': 'flop',
#      'pot': {'main': {'amount': 1180},
#       'side': [{'amount': 0, 'eligibles': ['uuid-0']}]},
#      'community_card': ['SK', 'S8', 'ST'],
#      'dealer_btn': 0,
#      'next_player': 3,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 0,
#        'state': 'allin'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 980, 'state': 'folded'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 960, 'state': 'folded'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 960,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 940,
#        'state': 'participating'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 980, 'state': 'folded'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': [{'action': 'FOLD', 'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 20,
#         'paid': 20,
#         'add_amount': 20,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'RAISE',
#         'amount': 40,
#         'paid': 40,
#         'add_amount': 20,
#         'uuid': 'uuid-4'},
#        {'action': 'FOLD', 'uuid': 'uuid-5'},
#        {'action': 'RAISE',
#         'amount': 980,
#         'paid': 980,
#         'add_amount': 940,
#         'uuid': 'uuid-0'},
#        {'action': 'FOLD', 'uuid': 'uuid-2'}]}}}],
#   14: [{'type': 'event_ask_player',
#     'uuid': 'uuid-4',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 980},
#      {'action': 'raise', 'amount': {'min': -1, 'max': -1}}],
#     'round_state': {'street': 'flop',
#      'pot': {'main': {'amount': 2140},
#       'side': [{'amount': 0, 'eligibles': ['uuid-0', 'uuid-3']},
#        {'amount': 0, 'eligibles': ['uuid-0', 'uuid-3']}]},
#      'community_card': ['SK', 'S8', 'ST'],
#      'dealer_btn': 0,
#      'next_player': 4,
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 0,
#        'state': 'allin'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 980, 'state': 'folded'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 960, 'state': 'folded'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 940,
#        'state': 'participating'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 980, 'state': 'folded'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': [{'action': 'FOLD', 'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 20,
#         'paid': 20,
#         'add_amount': 20,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'RAISE',
#         'amount': 40,
#         'paid': 40,
#         'add_amount': 20,
#         'uuid': 'uuid-4'},
#        {'action': 'FOLD', 'uuid': 'uuid-5'},
#        {'action': 'RAISE',
#         'amount': 980,
#         'paid': 980,
#         'add_amount': 940,
#         'uuid': 'uuid-0'},
#        {'action': 'FOLD', 'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 980, 'paid': 960, 'uuid': 'uuid-3'}]}}}],
#   15: [{'type': 'event_new_street',
#     'street': 'turn',
#     'round_state': {'street': 'turn',
#      'pot': {'main': {'amount': 2140},
#       'side': [{'amount': 0, 'eligibles': ['uuid-0', 'uuid-3']},
#        {'amount': 0, 'eligibles': ['uuid-0', 'uuid-3']}]},
#      'community_card': ['SK', 'S8', 'ST', 'S3'],
#      'dealer_btn': 0,
#      'next_player': 'not_found',
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 0,
#        'state': 'allin'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 980, 'state': 'folded'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 960, 'state': 'folded'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4', 'uuid': 'uuid-4', 'stack': 940, 'state': 'folded'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 980, 'state': 'folded'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': [{'action': 'FOLD', 'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 20,
#         'paid': 20,
#         'add_amount': 20,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'RAISE',
#         'amount': 40,
#         'paid': 40,
#         'add_amount': 20,
#         'uuid': 'uuid-4'},
#        {'action': 'FOLD', 'uuid': 'uuid-5'},
#        {'action': 'RAISE',
#         'amount': 980,
#         'paid': 980,
#         'add_amount': 940,
#         'uuid': 'uuid-0'},
#        {'action': 'FOLD', 'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 980, 'paid': 960, 'uuid': 'uuid-3'},
#        {'action': 'FOLD', 'uuid': 'uuid-4'}],
#       'turn': []}}},
#    {'type': 'event_new_street',
#     'street': 'river',
#     'round_state': {'street': 'river',
#      'pot': {'main': {'amount': 2140},
#       'side': [{'amount': 0, 'eligibles': ['uuid-0', 'uuid-3']},
#        {'amount': 0, 'eligibles': ['uuid-0', 'uuid-3']}]},
#      'community_card': ['SK', 'S8', 'ST', 'S3', 'C4'],
#      'dealer_btn': 0,
#      'next_player': 'not_found',
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 0,
#        'state': 'allin'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 980, 'state': 'folded'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 960, 'state': 'folded'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4', 'uuid': 'uuid-4', 'stack': 940, 'state': 'folded'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 980, 'state': 'folded'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': [{'action': 'FOLD', 'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 20,
#         'paid': 20,
#         'add_amount': 20,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'RAISE',
#         'amount': 40,
#         'paid': 40,
#         'add_amount': 20,
#         'uuid': 'uuid-4'},
#        {'action': 'FOLD', 'uuid': 'uuid-5'},
#        {'action': 'RAISE',
#         'amount': 980,
#         'paid': 980,
#         'add_amount': 940,
#         'uuid': 'uuid-0'},
#        {'action': 'FOLD', 'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 980, 'paid': 960, 'uuid': 'uuid-3'},
#        {'action': 'FOLD', 'uuid': 'uuid-4'}],
#       'turn': []}}},
#    {'type': 'event_round_finish',
#     'round_state': {'street': 'showdown',
#      'pot': {'main': {'amount': 2140},
#       'side': [{'amount': 0, 'eligibles': ['uuid-0', 'uuid-3']},
#        {'amount': 0, 'eligibles': ['uuid-0', 'uuid-3']}]},
#      'community_card': ['SK', 'S8', 'ST', 'S3', 'C4'],
#      'dealer_btn': 0,
#      'next_player': 'not_found',
#      'small_blind_pos': 1,
#      'big_blind_pos': 2,
#      'round_count': 1,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 2140,
#        'state': 'allin'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 980, 'state': 'folded'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 960, 'state': 'folded'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4', 'uuid': 'uuid-4', 'stack': 940, 'state': 'folded'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 980, 'state': 'folded'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 10, 'uuid': 'uuid-1'},
#        {'action': 'CALL', 'amount': 20, 'paid': 0, 'uuid': 'uuid-2'}],
#       'flop': [{'action': 'FOLD', 'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 20,
#         'paid': 20,
#         'add_amount': 20,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'RAISE',
#         'amount': 40,
#         'paid': 40,
#         'add_amount': 20,
#         'uuid': 'uuid-4'},
#        {'action': 'FOLD', 'uuid': 'uuid-5'},
#        {'action': 'RAISE',
#         'amount': 980,
#         'paid': 980,
#         'add_amount': 940,
#         'uuid': 'uuid-0'},
#        {'action': 'FOLD', 'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 980, 'paid': 960, 'uuid': 'uuid-3'},
#        {'action': 'FOLD', 'uuid': 'uuid-4'}],
#       'turn': []}},
#     'winners': [{'uuid': 'uuid-0', 'stack': 2140}]}]},
#  1: {0: [{'type': 'event_new_street',
#     'street': 'preflop',
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 30}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 1,
#      'next_player': 4,
#      'small_blind_pos': 2,
#      'big_blind_pos': 3,
#      'round_count': 2,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 2140,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 950,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 940,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-3'}]}}},
#    {'type': 'event_ask_player',
#     'uuid': 'uuid-4',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 940}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 30}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 1,
#      'next_player': 4,
#      'small_blind_pos': 2,
#      'big_blind_pos': 3,
#      'round_count': 2,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 2140,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 950,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 940,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-3'}]}}}],
#   1: [{'type': 'event_ask_player',
#     'uuid': 'uuid-5',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 980}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 50}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 1,
#      'next_player': 5,
#      'small_blind_pos': 2,
#      'big_blind_pos': 3,
#      'round_count': 2,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 2140,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 950,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 920,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 980,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'}]}}}],
#   2: [{'type': 'event_ask_player',
#     'uuid': 'uuid-0',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 2140}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 70}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 1,
#      'next_player': 0,
#      'small_blind_pos': 2,
#      'big_blind_pos': 3,
#      'round_count': 2,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 2140,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 950,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 920,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 960,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'}]}}}],
#   3: [{'type': 'event_ask_player',
#     'uuid': 'uuid-1',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 980}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 90}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 1,
#      'next_player': 1,
#      'small_blind_pos': 2,
#      'big_blind_pos': 3,
#      'round_count': 2,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 2120,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 950,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 920,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 960,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'}]}}}],
#   4: [{'type': 'event_ask_player',
#     'uuid': 'uuid-2',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 960}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 110}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 1,
#      'next_player': 2,
#      'small_blind_pos': 2,
#      'big_blind_pos': 3,
#      'round_count': 2,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 2120,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 960,
#        'state': 'participating'},
#       {'name': 'player2',
#        'uuid': 'uuid-2',
#        'stack': 950,
#        'state': 'participating'},
#       {'name': 'player3',
#        'uuid': 'uuid-3',
#        'stack': 980,
#        'state': 'participating'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 920,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 960,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-2'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-1'}]}}}],
#   5: [{'type': 'event_ask_player',
#     'uuid': 'uuid-3',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 20},
#      {'action': 'raise', 'amount': {'min': 30, 'max': 1000}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 120}, 'side': []},
#      'community_card': [],
#      'dealer_btn': 1,
#      'next_player': 3,
#      'small_blind_pos': 2,
#      'big_blind_pos': 3,
#      'round_count': 2,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 2120,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 960,
# ...
#      'community_card': [],
#      'dealer_btn': 4,
#      'next_player': 4,
#      'small_blind_pos': 5,
#      'big_blind_pos': 0,
#      'round_count': 5,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 1200,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 10,
#        'state': 'participating'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 0, 'state': 'allin'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4',
#        'uuid': 'uuid-4',
#        'stack': 850,
#        'state': 'participating'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 2000,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-5'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-0'},
#        {'action': 'RAISE',
#         'amount': 30,
#         'paid': 30,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 2860,
#         'paid': 2860,
#         'add_amount': 2830,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'}]}}}],
#   4: [{'type': 'event_ask_player',
#     'uuid': 'uuid-5',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 2860},
#      {'action': 'raise', 'amount': {'min': -1, 'max': -1}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 110},
#       'side': [{'amount': 1670, 'eligibles': ['uuid-2', 'uuid-4']},
#        {'amount': 2010, 'eligibles': ['uuid-2']},
#        {'amount': 0, 'eligibles': ['uuid-2']}]},
#      'community_card': [],
#      'dealer_btn': 4,
#      'next_player': 5,
#      'small_blind_pos': 5,
#      'big_blind_pos': 0,
#      'round_count': 5,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 1200,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 10,
#        'state': 'participating'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 0, 'state': 'allin'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4', 'uuid': 'uuid-4', 'stack': 0, 'state': 'allin'},
#       {'name': 'player5',
#        'uuid': 'uuid-5',
#        'stack': 2000,
#        'state': 'participating'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-5'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-0'},
#        {'action': 'RAISE',
#         'amount': 30,
#         'paid': 30,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 2860,
#         'paid': 2860,
#         'add_amount': 2830,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 850, 'paid': 850, 'uuid': 'uuid-4'}]}}}],
#   5: [{'type': 'event_ask_player',
#     'uuid': 'uuid-0',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 2860},
#      {'action': 'raise', 'amount': {'min': -1, 'max': -1}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 120},
#       'side': [{'amount': 2500, 'eligibles': ['uuid-2', 'uuid-4', 'uuid-5']},
#        {'amount': 2320, 'eligibles': ['uuid-2', 'uuid-5']},
#        {'amount': 850, 'eligibles': ['uuid-2']},
#        {'amount': 0, 'eligibles': ['uuid-2']}]},
#      'community_card': [],
#      'dealer_btn': 4,
#      'next_player': 0,
#      'small_blind_pos': 5,
#      'big_blind_pos': 0,
#      'round_count': 5,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 1200,
#        'state': 'participating'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 10,
#        'state': 'participating'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 0, 'state': 'allin'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4', 'uuid': 'uuid-4', 'stack': 0, 'state': 'allin'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 0, 'state': 'allin'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-5'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-0'},
#        {'action': 'RAISE',
#         'amount': 30,
#         'paid': 30,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 2860,
#         'paid': 2860,
#         'add_amount': 2830,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 850, 'paid': 850, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 2010, 'paid': 2000, 'uuid': 'uuid-5'}]}}}],
#   6: [{'type': 'event_ask_player',
#     'uuid': 'uuid-1',
#     'valid_actions': [{'action': 'fold', 'amount': 0},
#      {'action': 'call', 'amount': 2860},
#      {'action': 'raise', 'amount': {'min': -1, 'max': -1}}],
#     'round_state': {'street': 'preflop',
#      'pot': {'main': {'amount': 120},
#       'side': [{'amount': 3330,
#         'eligibles': ['uuid-0', 'uuid-2', 'uuid-4', 'uuid-5']},
#        {'amount': 1110, 'eligibles': ['uuid-0', 'uuid-2', 'uuid-5']},
#        {'amount': 1580, 'eligibles': ['uuid-2', 'uuid-5']},
#        {'amount': 850, 'eligibles': ['uuid-2']},
#        {'amount': 0, 'eligibles': ['uuid-2']}]},
#      'community_card': [],
#      'dealer_btn': 4,
#      'next_player': 1,
#      'small_blind_pos': 5,
#      'big_blind_pos': 0,
#      'round_count': 5,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 0,
#        'state': 'allin'},
#       {'name': 'player1',
#        'uuid': 'uuid-1',
#        'stack': 10,
#        'state': 'participating'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 0, 'state': 'allin'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4', 'uuid': 'uuid-4', 'stack': 0, 'state': 'allin'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 0, 'state': 'allin'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-5'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-0'},
#        {'action': 'RAISE',
#         'amount': 30,
#         'paid': 30,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 2860,
#         'paid': 2860,
#         'add_amount': 2830,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 850, 'paid': 850, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 2010, 'paid': 2000, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 1220, 'paid': 1200, 'uuid': 'uuid-0'}]}}}],
#   7: [{'type': 'event_new_street',
#     'street': 'flop',
#     'round_state': {'street': 'flop',
#      'pot': {'main': {'amount': 120},
#       'side': [{'amount': 100,
#         'eligibles': ['uuid-0', 'uuid-1', 'uuid-2', 'uuid-4', 'uuid-5']},
#        {'amount': 3240, 'eligibles': ['uuid-0', 'uuid-2', 'uuid-4', 'uuid-5']},
#        {'amount': 1110, 'eligibles': ['uuid-0', 'uuid-2', 'uuid-5']},
#        {'amount': 1580, 'eligibles': ['uuid-2', 'uuid-5']},
#        {'amount': 850, 'eligibles': ['uuid-2']},
#        {'amount': 0, 'eligibles': ['uuid-2']}]},
#      'community_card': ['D8', 'S5', 'ST'],
#      'dealer_btn': 4,
#      'next_player': 'not_found',
#      'small_blind_pos': 5,
#      'big_blind_pos': 0,
#      'round_count': 5,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 0,
#        'state': 'allin'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 0, 'state': 'allin'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 0, 'state': 'allin'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4', 'uuid': 'uuid-4', 'stack': 0, 'state': 'allin'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 0, 'state': 'allin'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-5'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-0'},
#        {'action': 'RAISE',
#         'amount': 30,
#         'paid': 30,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 2860,
#         'paid': 2860,
#         'add_amount': 2830,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 850, 'paid': 850, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 2010, 'paid': 2000, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 1220, 'paid': 1200, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 40, 'paid': 10, 'uuid': 'uuid-1'}],
#       'flop': []}}},
#    {'type': 'event_new_street',
#     'street': 'turn',
#     'round_state': {'street': 'turn',
#      'pot': {'main': {'amount': 120},
#       'side': [{'amount': 100,
#         'eligibles': ['uuid-0', 'uuid-1', 'uuid-2', 'uuid-4', 'uuid-5']},
#        {'amount': 3240, 'eligibles': ['uuid-0', 'uuid-2', 'uuid-4', 'uuid-5']},
#        {'amount': 1110, 'eligibles': ['uuid-0', 'uuid-2', 'uuid-5']},
#        {'amount': 1580, 'eligibles': ['uuid-2', 'uuid-5']},
#        {'amount': 850, 'eligibles': ['uuid-2']},
#        {'amount': 0, 'eligibles': ['uuid-2']}]},
#      'community_card': ['D8', 'S5', 'ST', 'S2'],
#      'dealer_btn': 4,
#      'next_player': 'not_found',
#      'small_blind_pos': 5,
#      'big_blind_pos': 0,
#      'round_count': 5,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 0,
#        'state': 'allin'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 0, 'state': 'allin'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 0, 'state': 'allin'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4', 'uuid': 'uuid-4', 'stack': 0, 'state': 'allin'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 0, 'state': 'allin'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-5'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-0'},
#        {'action': 'RAISE',
#         'amount': 30,
#         'paid': 30,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 2860,
#         'paid': 2860,
#         'add_amount': 2830,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 850, 'paid': 850, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 2010, 'paid': 2000, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 1220, 'paid': 1200, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 40, 'paid': 10, 'uuid': 'uuid-1'}],
#       'flop': []}}},
#    {'type': 'event_new_street',
#     'street': 'river',
#     'round_state': {'street': 'river',
#      'pot': {'main': {'amount': 120},
#       'side': [{'amount': 100,
#         'eligibles': ['uuid-0', 'uuid-1', 'uuid-2', 'uuid-4', 'uuid-5']},
#        {'amount': 3240, 'eligibles': ['uuid-0', 'uuid-2', 'uuid-4', 'uuid-5']},
#        {'amount': 1110, 'eligibles': ['uuid-0', 'uuid-2', 'uuid-5']},
#        {'amount': 1580, 'eligibles': ['uuid-2', 'uuid-5']},
#        {'amount': 850, 'eligibles': ['uuid-2']},
#        {'amount': 0, 'eligibles': ['uuid-2']}]},
#      'community_card': ['D8', 'S5', 'ST', 'S2', 'D6'],
#      'dealer_btn': 4,
#      'next_player': 'not_found',
#      'small_blind_pos': 5,
#      'big_blind_pos': 0,
#      'round_count': 5,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 0,
#        'state': 'allin'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 0, 'state': 'allin'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 0, 'state': 'allin'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4', 'uuid': 'uuid-4', 'stack': 0, 'state': 'allin'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 0, 'state': 'allin'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-5'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-0'},
#        {'action': 'RAISE',
#         'amount': 30,
#         'paid': 30,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 2860,
#         'paid': 2860,
#         'add_amount': 2830,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 850, 'paid': 850, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 2010, 'paid': 2000, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 1220, 'paid': 1200, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 40, 'paid': 10, 'uuid': 'uuid-1'}],
#       'flop': []}}},
#    {'type': 'event_round_finish',
#     'round_state': {'street': 'showdown',
#      'pot': {'main': {'amount': 120},
#       'side': [{'amount': 100,
#         'eligibles': ['uuid-0', 'uuid-1', 'uuid-2', 'uuid-4', 'uuid-5']},
#        {'amount': 3240, 'eligibles': ['uuid-0', 'uuid-2', 'uuid-4', 'uuid-5']},
#        {'amount': 1110, 'eligibles': ['uuid-0', 'uuid-2', 'uuid-5']},
#        {'amount': 1580, 'eligibles': ['uuid-2', 'uuid-5']},
#        {'amount': 850, 'eligibles': ['uuid-2']},
#        {'amount': 0, 'eligibles': ['uuid-2']}]},
#      'community_card': ['D8', 'S5', 'ST', 'S2', 'D6'],
#      'dealer_btn': 4,
#      'next_player': 'not_found',
#      'small_blind_pos': 5,
#      'big_blind_pos': 0,
#      'round_count': 5,
#      'small_blind_amount': 10,
#      'seats': [{'name': 'player0',
#        'uuid': 'uuid-0',
#        'stack': 0,
#        'state': 'allin'},
#       {'name': 'player1', 'uuid': 'uuid-1', 'stack': 0, 'state': 'allin'},
#       {'name': 'player2', 'uuid': 'uuid-2', 'stack': 850, 'state': 'allin'},
#       {'name': 'player3', 'uuid': 'uuid-3', 'stack': 0, 'state': 'allin'},
#       {'name': 'player4', 'uuid': 'uuid-4', 'stack': 0, 'state': 'allin'},
#       {'name': 'player5', 'uuid': 'uuid-5', 'stack': 6150, 'state': 'allin'}],
#      'action_histories': {'preflop': [{'action': 'SMALLBLIND',
#         'amount': 10,
#         'add_amount': 10,
#         'uuid': 'uuid-5'},
#        {'action': 'BIGBLIND',
#         'amount': 20,
#         'add_amount': 10,
#         'uuid': 'uuid-0'},
#        {'action': 'RAISE',
#         'amount': 30,
#         'paid': 30,
#         'add_amount': 10,
#         'uuid': 'uuid-1'},
#        {'action': 'RAISE',
#         'amount': 2860,
#         'paid': 2860,
#         'add_amount': 2830,
#         'uuid': 'uuid-2'},
#        {'action': 'CALL', 'amount': 20, 'paid': 20, 'uuid': 'uuid-3'},
#        {'action': 'CALL', 'amount': 850, 'paid': 850, 'uuid': 'uuid-4'},
#        {'action': 'CALL', 'amount': 2010, 'paid': 2000, 'uuid': 'uuid-5'},
#        {'action': 'CALL', 'amount': 1220, 'paid': 1200, 'uuid': 'uuid-0'},
#        {'action': 'CALL', 'amount': 40, 'paid': 10, 'uuid': 'uuid-1'}],
#       'flop': []}},
#     'winners': [{'uuid': 'uuid-5', 'stack': 6150}]},
#    {'type': 'event_game_finish',
#     'players': [{'uuid': 'uuid-0', 'stack': 0},
#      {'uuid': 'uuid-1', 'stack': 0},
#      {'uuid': 'uuid-2', 'stack': 850},
#      {'uuid': 'uuid-3', 'stack': 0},
#      {'uuid': 'uuid-4', 'stack': 0},
#      {'uuid': 'uuid-5', 'stack': 6150}]}]}}

# %%
pd.DataFrame.from_dict(data=events[0][0][0]['round_state'], orient='index').reset_index()
# Out:
#                  index                                                  0
# 0               street                                            preflop
# 1                  pot               {'main': {'amount': 30}, 'side': []}
# 2       community_card                                                 []
# 3           dealer_btn                                                  0
# 4          next_player                                                  3
# 5      small_blind_pos                                                  1
# 6        big_blind_pos                                                  2
# 7          round_count                                                  1
# 8   small_blind_amount                                                 10
# 9                seats  [{'name': 'player0', 'uuid': 'uuid-0', 'stack'...
# 10    action_histories  {'preflop': [{'action': 'SMALLBLIND', 'amount'...

# %%
pd.DataFrame.from_dict(data=events[1][0][0]['round_state'], orient='index').reset_index()
# Out:
#                  index                                                  0
# 0               street                                            preflop
# 1                  pot               {'main': {'amount': 30}, 'side': []}
# 2       community_card                                                 []
# 3           dealer_btn                                                  1
# 4          next_player                                                  4
# 5      small_blind_pos                                                  2
# 6        big_blind_pos                                                  3
# 7          round_count                                                  2
# 8   small_blind_amount                                                 10
# 9                seats  [{'name': 'player0', 'uuid': 'uuid-0', 'stack'...
# 10    action_histories  {'preflop': [{'action': 'SMALLBLIND', 'amount'...
